# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Compare Activation Functions

# %%
# 1. Load and preprocess MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalise pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten 28x28 images into vectors of size 784
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
# 2. Function to build MLP with different activation functions

def build_mlp(activation_fn):
    model = models.Sequential()
    model.add(layers.Input(shape=(784,)))
    model.add(layers.Dense(128, activation=activation))
    model.add(layers.Dense(64, activation=activation))
    model.add(layers.Dense(10, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# 3. Activations to compare

activations = ['sigmoid', 'tanh', 'relu', layers.LeakyReLU(alpha=0.01)]
history_results = {}
test_results = {}

for activation in activations:
    model = build_mlp(activation)
    history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2, verbose=1)

    history_results[str(activation)] = history.history
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    test_results[str(activation)] = test_acc
    print(f"Test accuracy for {activation}: {test_acc:.4f}")
# Out:
# Epoch 1/5
# 2025-08-25 16:25:00.224774: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 750/750 [==============================] - 1s 1ms/step - loss: 0.6803 - accuracy: 0.8417 - val_loss: 0.2861 - val_accuracy: 0.9223
# Epoch 2/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.2513 - accuracy: 0.9277 - val_loss: 0.2057 - val_accuracy: 0.9428
# Epoch 3/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1836 - accuracy: 0.9471 - val_loss: 0.1626 - val_accuracy: 0.9539
# Epoch 4/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1431 - accuracy: 0.9584 - val_loss: 0.1457 - val_accuracy: 0.9574
# Epoch 5/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1148 - accuracy: 0.9673 - val_loss: 0.1211 - val_accuracy: 0.9655
# Test accuracy for sigmoid: 0.9633
# Epoch 1/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.3275 - accuracy: 0.9064 - val_loss: 0.1931 - val_accuracy: 0.9453
# Epoch 2/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1550 - accuracy: 0.9543 - val_loss: 0.1404 - val_accuracy: 0.9582
# Epoch 3/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1074 - accuracy: 0.9690 - val_loss: 0.1102 - val_accuracy: 0.9688
# Epoch 4/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0787 - accuracy: 0.9762 - val_loss: 0.1049 - val_accuracy: 0.9686
# Epoch 5/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0600 - accuracy: 0.9816 - val_loss: 0.0949 - val_accuracy: 0.9727
# Test accuracy for tanh: 0.9734
# Epoch 1/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.3068 - accuracy: 0.9118 - val_loss: 0.1575 - val_accuracy: 0.9547
# Epoch 2/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1289 - accuracy: 0.9616 - val_loss: 0.1160 - val_accuracy: 0.9659
# Epoch 3/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0879 - accuracy: 0.9740 - val_loss: 0.1070 - val_accuracy: 0.9656
# Epoch 4/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0640 - accuracy: 0.9806 - val_loss: 0.0965 - val_accuracy: 0.9720
# Epoch 5/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0502 - accuracy: 0.9845 - val_loss: 0.0916 - val_accuracy: 0.9724
# Test accuracy for relu: 0.9742
# Epoch 1/5
# 750/750 [==============================] - 1s 2ms/step - loss: 0.3220 - accuracy: 0.9067 - val_loss: 0.1650 - val_accuracy: 0.9536
# Epoch 2/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.1331 - accuracy: 0.9602 - val_loss: 0.1332 - val_accuracy: 0.9602
# Epoch 3/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0906 - accuracy: 0.9725 - val_loss: 0.1161 - val_accuracy: 0.9654
# Epoch 4/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0699 - accuracy: 0.9789 - val_loss: 0.0975 - val_accuracy: 0.9693
# Epoch 5/5
# 750/750 [==============================] - 1s 1ms/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.1020 - val_accuracy: 0.9709
# Test accuracy for <keras.layers.activation.leaky_relu.LeakyReLU object at 0x3004151d0>: 0.9717

# %%
# 5. Plot accuracy curves for activation
plt.figure(figsize=(8, 6))
for activation, history in history_results.items():
  plt.plot(history['val_accuracy'], label=f'{activation}(Val acc)')

plt.title("Validation Accuracy for Different Activations")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curves for Different Activation Functions')
plt.legend()
plt.grid(True)

# %%
# 6. Plot training loss curves
plt.figure(figsize=(8, 6))
for activation, history in history_results.items():
  plt.plot(history['loss'], label=f'{activation}(Train loss)')

plt.title("Training Loss for Different Activations")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
